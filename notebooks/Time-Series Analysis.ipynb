# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('../data/processed/uk_sessions_2022-01-01_2022-11-01.csv')
df = df.rename(columns={'ENERGY_DELIVERED_KWH':'ENERGY'})
df['SESSION_STOP'] = pd.to_datetime(df['SESSION_STOP'])
df['DATE'] = df['SESSION_STOP'].dt.date
df_daily = df.groupby(['LOCATION_ID', 'DATE']).sum('ENERGY')
df_locations = df_daily.groupby('LOCATION_ID')

# %%
df1 = dict(list(df_locations))[766827].droplevel(level=0)
df1.sort_index(inplace=True)

# %%
print(df1['ENERGY'].autocorr(lag=1))
print(df1['ENERGY'].autocorr(lag=2))
print(df1['ENERGY'].autocorr(lag=3))
print(df1['ENERGY'].autocorr(lag=4))
# Out:
# 0.6337966198887572
# 0.5118181204753129
# 0.4451599549539851
# 0.48615748876966364

# %%
df1['ENERGY']
# Out:
# DATE
# 2022-01-01     664.015
# 2022-01-02     646.950
# 2022-01-03    1141.525
# 2022-01-04    1037.250
# 2022-01-05     869.325
#                 ...
# 2022-10-27    2961.670
# 2022-10-28    2601.069
# 2022-10-29    2755.868
# 2022-10-30    2814.614
# 2022-10-31    3237.099
# Name: ENERGY, Length: 303, dtype: float64

# %%
plt.plot(df1['ENERGY'])

# %%
result_add = seasonal_decompose(df1['ENERGY'], model ='add')
result_add.plot();
result_mul = seasonal_decompose(df1['ENERGY'], model = 'mul')
result_mul.plot();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 result_add = seasonal_decompose(df1['ENERGY'], model ='add')
#       2 result_add.plot();
#       3 result_mul = seasonal_decompose(df1['ENERGY'], model = 'mul')
#
# File c:\Users\tijmen.vanetten\AppData\Local\miniconda3\envs\charging_demand\lib\site-packages\statsmodels\tsa\seasonal.py:159, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157         period = pfreq
#     158     else:
# --> 159         raise ValueError(
#     160             "You must specify a period or x must be a pandas object with "
#     161             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162         )
#     163 if x.shape[0] < 2 * pfreq:
#     164     raise ValueError(
#     165         f"x must have 2 complete cycles requires {2 * pfreq} "
#     166         f"observations. x only has {x.shape[0]} observation(s)"
#     167     )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %%
df_daily['ENERGY_NAIVE_PRED'] = df_daily['ENERGY'].shift(1)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
indices = df_daily['ENERGY_NAIVE_PRED'].dropna().index
mean_absolute_percentage_error(df_daily['ENERGY'][indices], df_daily['ENERGY_NAIVE_PRED'][indices])

# %%
df_daily[['ENERGY_NAIVE_PRED', 'ENERGY']].plot()
