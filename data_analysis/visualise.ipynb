# %%
import sys
import os
sys.path.insert(1, os.path.join(sys.path[0], '../src'))

# %%
from data import data_handler
from visualization import plot_series
import matplotlib.pyplot as plt

# %% [markdown]
# ## Shell Dataset Subset

# %%
series_list = data_handler('shell')
print(len(series_list))
print([len(series) for series in series_list])
series_list = [series for series in series_list if len(series) == 1035][:6]
# Out:
# 113
# [1035, 1035, 1034, 1035, 1035, 1031, 1034, 909, 198, 1033, 1035, 798, 900, 1035, 1035, 1032, 1035, 953, 1034, 1035, 66, 1035, 1006, 1035, 1035, 1020, 1035, 1028, 1035, 1015, 1035, 1035, 1019, 1034, 1034, 1034, 1034, 1032, 1034, 1034, 896, 1030, 1035, 1015, 1006, 1031, 1034, 206, 1032, 1019, 1034, 1031, 304, 1025, 997, 1035, 952, 1035, 1034, 1035, 1035, 304, 865, 830, 592, 830, 826, 839, 777, 683, 351, 451, 729, 746, 735, 733, 726, 712, 699, 654, 401, 611, 629, 595, 478, 502, 328, 327, 366, 350, 917, 313, 715, 568, 642, 432, 488, 706, 658, 258, 636, 315, 272, 146, 209, 235, 209, 106, 186, 96, 60, 57, 4]

# %%
fig, axs = plot_series(series_list)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Palo Alto Dataset Subset

# %%
series_list = data_handler('palo_alto')

# %%
fig, axs = plot_series(series_list)[:6]
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
